# %%
import sys
import os
import requests

import torch
import numpy as np

import matplotlib.pyplot as plt
from PIL import Image
import models_mae
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 10
#       8 import matplotlib.pyplot as plt
#       9 from PIL import Image
# ---> 10 import models_mae
#
# ModuleNotFoundError: No module named 'models_mae'
