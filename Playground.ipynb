# %% [markdown]
# # Playground

# %%
# Import Libraries
import cv2
import numpy as np
from scipy import ndimage
from PIL import Image 
import matplotlib.pyplot as plt

# %%
# Load in blurry sample image as well as target image
target_image = cv2.cvtColor(cv2.imread('sample_monkey.jpg'), cv2.COLOR_BGR2RGB)
sample_image = cv2.cvtColor(cv2.blur(cv2.imread('sample_monkey.jpg'), (15,15)), cv2.COLOR_BGR2RGB)

# %%
plt.imshow(target_image)
plt.show()

plt.imshow(sample_image)
plt.show()

plt.imshow(sample_image -
